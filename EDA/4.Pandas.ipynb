# %% [markdown]
# # Numpy

# %% [markdown]
# ## Pandas

# %%
import numpy as np
# arrays and numerical calculations
import pandas as pd
# data preprocessing and analysis
import matplotlib.pyplot as plt
import seaborn as sns
# data visualization libaries

# %%
a1 = np.random.randint(10, 100, 20).reshape(5, 4)
a2 = np.random.randint(10, 100, 24).reshape(6, 4)

# %%
a1.reshape(4, -1)
# Out:
# array([[30, 44, 41, 17, 98],
#        [93, 79, 46, 40, 36],
#        [30, 82, 77, 85, 71],
#        [45, 89, 65, 91, 56]])

# %%
a = np.array([1, 2, 3, 4, 5, 6, 7, 8])

# %%
a.reshape(-1, 1)
# Out:
# array([[1],
#        [2],
#        [3],
#        [4],
#        [5],
#        [6],
#        [7],
#        [8]])

# %%
x = np.array([1, 2,3 , 4])
y = np.array([4, 5, 3, 1])

# %%
z = np.append(x, y)

# %%
z
# Out:
# array([1, 2, 3, 4, 4, 5, 3, 1])

# %%
a1 # jaipur
# course, month
# Out:
# array([[30, 44, 41, 17],
#        [98, 93, 79, 46],
#        [40, 36, 30, 82],
#        [77, 85, 71, 45],
#        [89, 65, 91, 56]])

# %%
a2 # delhi
# course, month
# Out:
# array([[12, 56, 18, 27],
#        [83, 60, 94, 94],
#        [10, 46, 58, 91],
#        [19, 41, 34, 31],
#        [13, 89, 57, 47],
#        [27, 72, 37, 54]])

# %%
np.append(a1, a2)
# Out:
# array([30, 44, 41, 17, 98, 93, 79, 46, 40, 36, 30, 82, 77, 85, 71, 45, 89,
#        65, 91, 56, 12, 56, 18, 27, 83, 60, 94, 94, 10, 46, 58, 91, 19, 41,
#        34, 31, 13, 89, 57, 47, 27, 72, 37, 54])

# %%
a3 = np.append(a1, a2, axis=0)

# %%
a3
# Out:
# array([[30, 44, 41, 17],
#        [98, 93, 79, 46],
#        [40, 36, 30, 82],
#        [77, 85, 71, 45],
#        [89, 65, 91, 56],
#        [12, 56, 18, 27],
#        [83, 60, 94, 94],
#        [10, 46, 58, 91],
#        [19, 41, 34, 31],
#        [13, 89, 57, 47],
#        [27, 72, 37, 54]])

# %%
a1
# Out:
# array([[30, 44, 41, 17],
#        [98, 93, 79, 46],
#        [40, 36, 30, 82],
#        [77, 85, 71, 45],
#        [89, 65, 91, 56]])

# %%
a2 = a2[:5, :2]

# %%
a1
# Out:
# array([[30, 44, 41, 17],
#        [98, 93, 79, 46],
#        [40, 36, 30, 82],
#        [77, 85, 71, 45],
#        [89, 65, 91, 56]])

# %%
a2
# Out:
# array([[12, 56],
#        [83, 60],
#        [10, 46],
#        [19, 41],
#        [13, 89]])

# %%
a4 = np.append(a1, a2, axis=1)

# %%
a4
# Out:
# array([[30, 44, 41, 17, 12, 56],
#        [98, 93, 79, 46, 83, 60],
#        [40, 36, 30, 82, 10, 46],
#        [77, 85, 71, 45, 19, 41],
#        [89, 65, 91, 56, 13, 89]])

# %%
a1 = np.random.randint(10, 100, 100).reshape(20, 5)

# %%
a2 = np.random.randint(10, 100, 40).reshape(-1, 5)

# %%
a1
# Out:
# array([[64, 50, 24, 51, 15],
#        [80, 76, 22, 12, 46],
#        [20, 82, 19, 58, 30],
#        [97, 43, 83, 52, 33],
#        [94, 62, 80, 23, 53],
#        [91, 46, 37, 46, 86],
#        [76, 51, 81, 41, 74],
#        [85, 42, 69, 79, 81],
#        [18, 74, 26, 76, 58],
#        [58, 84, 64, 20, 21],
#        [51, 39, 33, 31, 89],
#        [87, 72, 41, 93, 16],
#        [59, 75, 79, 28, 90],
#        [73, 36, 23, 54, 55],
#        [17, 32, 19, 78, 98],
#        [45, 55, 78, 69, 52],
#        [66, 91, 65, 96, 11],
#        [51, 82, 47, 72, 48],
#        [31, 91, 22, 87, 94],
#        [71, 84, 80, 84, 91]])

# %%
a2.shape
# Out:
# (8, 5)

# %%
a2
# Out:
# array([[62, 77, 85, 58, 41],
#        [52, 14, 67, 48, 60],
#        [12, 14, 98, 98, 83],
#        [97, 30, 83, 65, 19],
#        [44, 59, 46, 21, 29],
#        [17, 60, 21, 14, 44],
#        [65, 70, 93, 29, 60],
#        [71, 27, 78, 17, 30]])

# %%
a1.shape
# Out:
# (20, 5)

# %%
a2.shape
# Out:
# (8, 5)

# %%
np.vstack([a1, a2])
# Out:
# array([[64, 50, 24, 51, 15],
#        [80, 76, 22, 12, 46],
#        [20, 82, 19, 58, 30],
#        [97, 43, 83, 52, 33],
#        [94, 62, 80, 23, 53],
#        [91, 46, 37, 46, 86],
#        [76, 51, 81, 41, 74],
#        [85, 42, 69, 79, 81],
#        [18, 74, 26, 76, 58],
#        [58, 84, 64, 20, 21],
#        [51, 39, 33, 31, 89],
#        [87, 72, 41, 93, 16],
#        [59, 75, 79, 28, 90],
#        [73, 36, 23, 54, 55],
#        [17, 32, 19, 78, 98],
#        [45, 55, 78, 69, 52],
#        [66, 91, 65, 96, 11],
#        [51, 82, 47, 72, 48],
#        [31, 91, 22, 87, 94],
#        [71, 84, 80, 84, 91],
#        [62, 77, 85, 58, 41],
#        [52, 14, 67, 48, 60],
#        [12, 14, 98, 98, 83],
#        [97, 30, 83, 65, 19],
#        [44, 59, 46, 21, 29],
#        [17, 60, 21, 14, 44],
#        [65, 70, 93, 29, 60],
#        [71, 27, 78, 17, 30]])

# %%
a1 = a1[:8, :3]

# %%
a1
# Out:
# array([[64, 50, 24],
#        [80, 76, 22],
#        [20, 82, 19],
#        [97, 43, 83],
#        [94, 62, 80],
#        [91, 46, 37],
#        [76, 51, 81],
#        [85, 42, 69]])

# %%
a2
# Out:
# array([[62, 77, 85, 58, 41],
#        [52, 14, 67, 48, 60],
#        [12, 14, 98, 98, 83],
#        [97, 30, 83, 65, 19],
#        [44, 59, 46, 21, 29],
#        [17, 60, 21, 14, 44],
#        [65, 70, 93, 29, 60],
#        [71, 27, 78, 17, 30]])

# %%
a1 = np.random.randint(10, 100, 100).reshape(20, 5)
a2 = np.random.randint(10, 100, 100).reshape(20, 5)

# %%
np.stack((a1, a2))
# Out:
# array([[[94, 75, 56, 19, 68],
#         [22, 79, 45, 18, 62],
#         [34, 27, 94, 30, 81],
#         [48, 92, 77, 21, 90],
#         [25, 75, 35, 91, 87],
#         [38, 35, 47, 11, 26],
#         [33, 28, 26, 27, 23],
#         [87, 50, 36, 56, 99],
#         [47, 43, 96, 41, 66],
#         [72, 20, 29, 45, 42],
#         [88, 24, 61, 34, 90],
#         [42, 93, 86, 18, 16],
#         [83, 66, 22, 74, 38],
#         [81, 70, 76, 21, 57],
#         [26, 56, 79, 69, 45],
#         [58, 37, 38, 25, 99],
#         [44, 42, 71, 99, 19],
#         [19, 10, 22, 83, 71],
#         [63, 63, 73, 49, 57],
#         [57, 57, 19, 52, 90]],
#
#        [[65, 94, 69, 72, 23],
#         [49, 44, 36, 12, 91],
#         [26, 24, 41, 87, 25],
#         [43, 18, 82, 36, 75],
#         [57, 22, 79, 35, 28],
#         [88, 19, 87, 41, 23],
#         [95, 77, 43, 41, 68],
#         [99, 23, 84, 61, 82],
#         [44, 49, 84, 53, 61],
#         [80, 62, 69, 12, 10],
#         [15, 61, 16, 65, 40],
# ...

# %%
np.stack((a1, a2), axis=1)
# Out:
# array([[[94, 75, 56, 19, 68],
#         [65, 94, 69, 72, 23]],
#
#        [[22, 79, 45, 18, 62],
#         [49, 44, 36, 12, 91]],
#
#        [[34, 27, 94, 30, 81],
#         [26, 24, 41, 87, 25]],
#
#        [[48, 92, 77, 21, 90],
#         [43, 18, 82, 36, 75]],
#
#        [[25, 75, 35, 91, 87],
#         [57, 22, 79, 35, 28]],
#
#        [[38, 35, 47, 11, 26],
#         [88, 19, 87, 41, 23]],
#
#        [[33, 28, 26, 27, 23],
#         [95, 77, 43, 41, 68]],
#
#        [[87, 50, 36, 56, 99],
#         [99, 23, 84, 61, 82]],
#
#        [[47, 43, 96, 41, 66],
#         [44, 49, 84, 53, 61]],
#
#        [[72, 20, 29, 45, 42],
#         [80, 62, 69, 12, 10]],
#
#        [[88, 24, 61, 34, 90],
#         [15, 61, 16, 65, 40]],
#
#        [[42, 93, 86, 18, 16],
#         [82, 71, 97, 86, 59]],
#
#        [[83, 66, 22, 74, 38],
#         [20, 63, 42, 17, 60]],
#
#        [[81, 70, 76, 21, 57],
#         [56, 41, 24, 97, 96]],
#
#        [[26, 56, 79, 69, 45],
# ...

# %%
blk = np.zeros((1080, 1920), dtype=np.uint8)
plt.imshow(blk, cmap='binary')
plt.show()

# %%
blk = np.ones((1080, 1920), dtype=np.uint8)*255
plt.imshow(blk, cmap='binary')
plt.show()

# %%
img = np.random.randint(0, 255, 1920*1080, dtype=np.uint8).reshape(1080, 1920)

# %%
plt.imshow(img, cmap='binary')
plt.show()

# %%
img[400:600, :] = 0

# %%
plt.imshow(img, cmap='binary')
plt.show()

# %%
img[:, 800:1000] = 0

# %%
plt.imshow(img, cmap='binary')
plt.show()

# %%
img[:200, :200] = 255
plt.imshow(img, cmap='binary')
plt.show()

# %%
plt.imsave("blk.jpg", img)

# %% [markdown]
# ### ROI
#
#     Rezion of interest

# %%
blk = np.zeros((1080, 1920, 3))

# %%
plt.imshow(blk)
plt.show()

# %%
white = np.ones((1080, 1920, 3), dtype=np.uint8)*255

# %%
plt.imshow(white)
plt.show()

# %%
arr = np.zeros((1080, 1920, 3), dtype=np.uint8)
arr[:, :, 0] = 255
plt.imshow(arr)
plt.show()

# %%
arr = np.zeros((1080, 1920, 3), dtype=np.uint8)
arr[:, :, 1] = 255
plt.imshow(arr)
plt.show()

# %%
arr = np.zeros((1080, 1920, 3), dtype=np.uint8)
arr[:, :, 2] = 255
plt.imshow(arr)
plt.show()

# %%
arr = np.zeros((1080, 1920, 3), dtype=np.uint8)
arr[:, :, :2] = 255
plt.imshow(arr)
plt.show()

# %%
arr = np.zeros((1080, 1920, 3), dtype=np.uint8)
arr[:, :, 1:] = 255
plt.imshow(arr)
plt.show()

# %%
arr = np.zeros((1080, 1920, 3), dtype=np.uint8)
arr[:, :, ::2] = 255
plt.imshow(arr)
plt.show()

# %% [markdown]
#     RGBCYMK

# %%
arr = np.zeros((1080, 1920, 3), dtype=np.uint8)
arr[:, :, :] = [120, 120, 250]
plt.imshow(arr)
plt.show()

# %%
img = plt.imread("one.jpg")

# %%
print(type(img))
print(img.shape)
print(img.dtype)
# Out:
# <class 'numpy.ndarray'>
# (2160, 3840, 3)
# uint8

# %%
plt.imshow(img)
plt.show()

# %%
img.shape
# Out:
# (2160, 3840, 3)

# %%
new_img = img.copy()

# %%
new_img[:, :, :] = new_img.mean(axis=2).reshape(2160, 3840, 1)

# %%
new_img.shape
# Out:
# (2160, 3840, 3)

# %%
plt.imshow(new_img)
plt.show()

# %%
new_img = img.copy()
new_img[:, :, 1:] = 0
plt.imshow(new_img)
plt.show()

# %%
new_img = img.copy()
new_img[:, :, 0] = new_img[:, :, 1]
plt.imshow(new_img)
plt.show()

# %%
plt.imshow(np.fliplr(img))
plt.show()

# %%
plt.imshow(np.flipud(img))
plt.show()

# %% [markdown]
# ## Pandas
#
#     Python Library for Data Analysis and Data Preprocessing & Modeling

# %% [markdown]
# ### Data Structures
#
#     1. Series
#
#         1D array like object which represents a Column or Random Variable
#
#     2. Data Frame
#
#         collection of Series, Spreadsheet or Table like Object
#         2D
#             rows -> observation
#             columns -> Random Varaibles (Series)
#
#     3. Pannel
#
#         collection of DataFrames
#         3D

# %% [markdown]
# ### Series
#
#     1D Array Like Object

# %%
import pandas as pd

# %%
height = pd.Series([140, 160, 180, 120, 190, 110])

# %%
height
# Out:
# 0    140
# 1    160
# 2    180
# 3    120
# 4    190
# 5    110
# dtype: int64

# %%
print(type(height))
print(height.shape)
print(height.size)
print(height.dtype)
# Out:
# <class 'pandas.core.series.Series'>
# (6,)
# 6
# int64

# %%
height.values
# Out:
# array([140, 160, 180, 120, 190, 110], dtype=int64)

# %%
h = np.array([140, 160, 180, 120, 190, 110], dtype=np.int32)
lb = ['vijay', 'sam', 'tanvi', 'rahul', 'sachin', 'rajat']

# %%
h
# Out:
# array([140, 160, 180, 120, 190, 110])

# %%
height = pd.Series(h, index=lb, name="height", dtype=np.int32)

# %%
height.name
# Out:
# 'height'

# %%
height.index
# Out:
# Index(['vijay', 'sam', 'tanvi', 'rahul', 'sachin', 'rajat'], dtype='object')

# %%
height.values
# Out:
# array([140, 160, 180, 120, 190, 110])

# %%
height
# Out:
# vijay     140
# sam       160
# tanvi     180
# rahul     120
# sachin    190
# rajat     110
# Name: height, dtype: int32

# %%
height[0]
# Out:
# 140

# %%
height['tanvi':'sachin']
# Out:
# tanvi     180
# rahul     120
# sachin    190
# Name: height, dtype: int32

# %%
height[2:4]
# Out:
# tanvi    180
# rahul    120
# Name: height, dtype: int32

# %%
height[::-2]
# Out:
# rajat    110
# rahul    120
# sam      160
# Name: height, dtype: int32

# %%
height[:2]
# Out:
# vijay    140
# sam      160
# Name: height, dtype: int32

# %%
height['sachin']
# Out:
# 190

# %%
height[-2]
# Out:
# 190

# %%
x = pd.Series(h, [2, 3, 4, 5, 6, 7])

# %%
x
# Out:
# 2    140
# 3    160
# 4    180
# 5    120
# 6    190
# 7    110
# dtype: int32

# %% [markdown]
# `loc` - indexing or slicing using row labels
#
# `iloc` - indeing or slicing using default indexes

# %%
x.iloc[0] # default indexing
# Out:
# 140

# %%
x.loc[2] # label indexing
# Out:
# 140

# %%
x.iloc[1::2]
# Out:
# 3    160
# 5    120
# 7    110
# dtype: int32

# %%
x.loc[3:7]
# Out:
# 3    160
# 4    180
# 5    120
# 6    190
# 7    110
# dtype: int32

# %%
height
# Out:
# vijay     140
# sam       160
# tanvi     180
# rahul     120
# sachin    190
# rajat     110
# Name: height, dtype: int32

# %%
ix = pd.date_range("2022-07-01", "2022-07-15")

# %%
ix.shape
# Out:
# (15,)

# %%
ix
# Out:
# DatetimeIndex(['2022-07-01', '2022-07-02', '2022-07-03', '2022-07-04',
#                '2022-07-05', '2022-07-06', '2022-07-07', '2022-07-08',
#                '2022-07-09', '2022-07-10', '2022-07-11', '2022-07-12',
#                '2022-07-13', '2022-07-14', '2022-07-15'],
#               dtype='datetime64[ns]', freq='D')

# %%
sales = pd.Series(np.random.randint(50, 80, 15), ix)

# %%
sales
# Out:
# 2022-07-01    70
# 2022-07-02    62
# 2022-07-03    59
# 2022-07-04    73
# 2022-07-05    53
# 2022-07-06    73
# 2022-07-07    74
# 2022-07-08    74
# 2022-07-09    60
# 2022-07-10    52
# 2022-07-11    50
# 2022-07-12    55
# 2022-07-13    52
# 2022-07-14    68
# 2022-07-15    63
# Freq: D, dtype: int32

# %%
sales["2022-07-05":"2022-07-10"]
# Out:
# 2022-07-05    53
# 2022-07-06    73
# 2022-07-07    74
# 2022-07-08    74
# 2022-07-09    60
# 2022-07-10    52
# Freq: D, dtype: int32

# %%
sales["2022-07-05":"2022-07-10"].mean()
# Out:
# 64.33333333333333

# %%
sales["2022-07-05":"2022-07-10"].median()
# Out:
# 66.5

# %%
sales["2022-07-05":"2022-07-10"].std()
# Out:
# 10.595596569644707

# %%
sales["2022-07-05":"2022-07-10"].var()
# Out:
# 112.26666666666668

# %%
sales["2022-07-05":"2022-07-10"].quantile([0.25, 0.5, 0.75])
# Out:
# 0.25    54.75
# 0.50    66.50
# 0.75    73.75
# dtype: float64

# %%
sales["2022-07-05":"2022-07-10"].describe()
# Out:
# count     6.000000
# mean     64.333333
# std      10.595597
# min      52.000000
# 25%      54.750000
# 50%      66.500000
# 75%      73.750000
# max      74.000000
# dtype: float64

# %%
sales.plot()
plt.show()

# %%
height.plot(kind='bar')
plt.show()

# %%
height.plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='height'>

# %%
s = pd.Series(np.random.choice(["male", "female", "other"], 100))

# %%
dt = pd.CategoricalDtype(["male", "female", "other"])
s1 = s.astype(dt)

# %%
s1
# Out:
# 0      other
# 1       male
# 2       male
# 3      other
# 4     female
#        ...
# 95     other
# 96      male
# 97    female
# 98    female
# 99      male
# Length: 100, dtype: category
# Categories (3, object): ['male', 'female', 'other']

# %%
s1.value_counts()
# Out:
# female    39
# male      33
# other     28
# dtype: int64

# %%
s1.value_counts().plot(kind='bar', color=['r', 'g', 'b'])
# Out:
# <AxesSubplot:>

# %%
height
# Out:
# vijay     140
# sam       160
# tanvi     180
# rahul     120
# sachin    190
# rajat     110
# Name: height, dtype: int32

# %%
height["tanvi"] = 155

# %%
height
# Out:
# vijay     140
# sam       160
# tanvi     155
# rahul     120
# sachin    190
# rajat     110
# Name: height, dtype: int32

# %%
height[-3:] += 5

# %%
height
# Out:
# vijay     140
# sam       160
# tanvi     155
# rahul     125
# sachin    195
# rajat     115
# Name: height, dtype: int32

# %%
height<=130
# Out:
# vijay     False
# sam       False
# tanvi     False
# rahul      True
# sachin    False
# rajat      True
# Name: height, dtype: bool

# %%
height[height<=130]
# Out:
# rahul    125
# rajat    115
# Name: height, dtype: int32

# %%
height[height<=130] += 10

# %%
height
# Out:
# vijay     140
# sam       160
# tanvi     155
# rahul     135
# sachin    195
# rajat     125
# Name: height, dtype: int32

# %%
s2 = pd.Series([10, 20, 25, 60, 90], ["sam", "vijay", "sachin", "rajat", "rahul"])

# %%
s2
# Out:
# sam       10
# vijay     20
# sachin    25
# rajat     60
# rahul     90
# dtype: int64

# %%
height + s2 # series and data frame operation happens according to row labels (indexes)
# index alignment happens automatically
# Out:
# rahul     225.0
# rajat     185.0
# sachin    220.0
# sam       170.0
# tanvi       NaN
# vijay     160.0
# dtype: float64

# %%
height.append(pd.Series([155, 120, 130], ['yadvendra', 'kushal', 'nidhi']))
# Out:
# vijay        140
# sam          160
# tanvi        155
# rahul        135
# sachin       195
# rajat        125
# yadvendra    155
# kushal       120
# nidhi        130
# dtype: int64

# %%
height
# Out:
# vijay     140
# sam       160
# tanvi     155
# rahul     135
# sachin    195
# rajat     125
# Name: height, dtype: int32

# %% [markdown]
# #### Data Frame

# %% [markdown]
# 15 minute break
#
#     1:10 PM

# %% [markdown]
# ### Data Frame
#
#     2D spreadsheet like object

# %% [markdown]
#     html, json, csv, execl, hd5, ... ?

# %%
data = [
    ["A", 50, 60, 80],
    ["B", 56, 45, 87],
    ["C", 56, 45, 87],
    ["D", 58, 79, 34],
    ["E", 34, 76, 87]
]

# %%
df = pd.DataFrame(data, columns=["name", "maths", "chemistry", "physics"])

# %%
df
# Out:
#   name  maths  chemistry  physics
# 0    A     50         60       80
# 1    B     56         45       87
# 2    C     56         45       87
# 3    D     58         79       34
# 4    E     34         76       87

# %%
df.shape
# Out:
# (5, 4)

# %%
df.dtypes
# Out:
# name         object
# maths         int64
# chemistry     int64
# physics       int64
# dtype: object

# %%
df
# Out:
#   name  maths  chemistry  physics
# 0    A     50         60       80
# 1    B     56         45       87
# 2    C     56         45       87
# 3    D     58         79       34
# 4    E     34         76       87

# %%
df["physics"] # 1D Series
# Out:
# 0    80
# 1    87
# 2    87
# 3    34
# 4    87
# Name: physics, dtype: int64

# %%
df[["name"]] # 2D DataFrame
# Out:
#   name
# 0    A
# 1    B
# 2    C
# 3    D
# 4    E

# %%
df
# Out:
#   name  maths  chemistry  physics
# 0    A     50         60       80
# 1    B     56         45       87
# 2    C     56         45       87
# 3    D     58         79       34
# 4    E     34         76       87

# %%
df[['name', 'physics']]
# Out:
#   name  physics
# 0    A       80
# 1    B       87
# 2    C       87
# 3    D       34
# 4    E       87

# %%
df[:5]
# Out:
#   name  maths  chemistry  physics
# 0    A     50         60       80
# 1    B     56         45       87
# 2    C     56         45       87
# 3    D     58         79       34
# 4    E     34         76       87

# %%
df[:2]
# Out:
#   name  maths  chemistry  physics
# 0    A     50         60       80
# 1    B     56         45       87

# %%
df[-2:]
# Out:
#   name  maths  chemistry  physics
# 3    D     58         79       34
# 4    E     34         76       87

# %%
height.head()
# Out:
# vijay     140
# sam       160
# tanvi     155
# rahul     135
# sachin    195
# Name: height, dtype: int32

# %%
height.head(2)
# Out:
# vijay    140
# sam      160
# Name: height, dtype: int32

# %%
height.tail(5)
# Out:
# sam       160
# tanvi     155
# rahul     135
# sachin    195
# rajat     125
# Name: height, dtype: int32

# %%
height.tail(2)
# Out:
# sachin    195
# rajat     125
# Name: height, dtype: int32

# %%
df
# Out:
#   name  maths  chemistry  physics
# 0    A     50         60       80
# 1    B     56         45       87
# 2    C     56         45       87
# 3    D     58         79       34
# 4    E     34         76       87

# %%
df.head(3)
# Out:
#   name  maths  chemistry  physics
# 0    A     50         60       80
# 1    B     56         45       87
# 2    C     56         45       87

# %%
df.tail(3)
# Out:
#   name  maths  chemistry  physics
# 2    C     56         45       87
# 3    D     58         79       34
# 4    E     34         76       87

# %%
df[::2]
# Out:
#   name  maths  chemistry  physics
# 0    A     50         60       80
# 2    C     56         45       87
# 4    E     34         76       87

# %%
df["name"]
# Out:
# 0    A
# 1    B
# 2    C
# 3    D
# 4    E
# Name: name, dtype: object

# %%
df[["name", "maths"]]
# Out:
#   name  maths
# 0    A     50
# 1    B     56
# 2    C     56
# 3    D     58
# 4    E     34

# %%
df
# Out:
#   name  maths  chemistry  physics
# 0    A     50         60       80
# 1    B     56         45       87
# 2    C     56         45       87
# 3    D     58         79       34
# 4    E     34         76       87

# %%
df['physics'] += 2

# %%
df
# Out:
#   name  maths  chemistry  physics
# 0    A     50         60       82
# 1    B     56         45       89
# 2    C     56         45       89
# 3    D     58         79       36
# 4    E     34         76       89

# %%
df[:3]['physics'] += 1
# Out:
# <ipython-input-266-427c73e96a37>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[:3]['physics'] += 1

# %%
df
# Out:
#   name  maths  chemistry  physics
# 0    A     50         60       83
# 1    B     56         45       90
# 2    C     56         45       90
# 3    D     58         79       36
# 4    E     34         76       89

# %%
df.columns # index on axis-1
# Out:
# Index(['name', 'maths', 'chemistry', 'physics'], dtype='object')

# %%
df.index # index on axis-0
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
df.index = [1001, 1010, 1007, 1313, 1111]

# %%
df
# Out:
#      name  maths  chemistry  physics
# 1001    A     50         60       83
# 1010    B     56         45       90
# 1007    C     56         45       90
# 1313    D     58         79       36
# 1111    E     34         76       89

# %%
data = [
    ["A", 50, 60, 80],
    ["B", 56, 45, 87],
    ["C", 56, 45, 87],
    ["D", 58, 79, 34],
    ["E", 34, 76, 87]
]

df = pd.DataFrame(
    data, 
    columns=["name", "maths", "chemistry", "physics"],
    index=[1001, 1010, 1007, 1313, 1111]
)

# %%
df
# Out:
#      name  maths  chemistry  physics
# 1001    A     50         60       80
# 1010    B     56         45       87
# 1007    C     56         45       87
# 1313    D     58         79       34
# 1111    E     34         76       87

# %%
df.set_index('name') # copy of DataFrame
# inplace=True -> change in original DataFrame
# Out:
#       maths  chemistry  physics
# name
# A        50         60       80
# B        56         45       87
# C        56         45       87
# D        58         79       34
# E        34         76       87

# %%
df
# Out:
#      name  maths  chemistry  physics
# 1001    A     50         60       80
# 1010    B     56         45       87
# 1007    C     56         45       87
# 1313    D     58         79       34
# 1111    E     34         76       87

# %%
df.reset_index()
# Out:
#    index name  maths  chemistry  physics
# 0   1001    A     50         60       80
# 1   1010    B     56         45       87
# 2   1007    C     56         45       87
# 3   1313    D     58         79       34
# 4   1111    E     34         76       87

# %%
df
# Out:
#      name  maths  chemistry  physics
# 1001    A     50         60       80
# 1010    B     56         45       87
# 1007    C     56         45       87
# 1313    D     58         79       34
# 1111    E     34         76       87

# %%
df.loc[1111, 'maths'] # 34

# %%
df.at[1111, 'maths'] # 34

# %%
df.iat[4, 1]

# %% [markdown]
#     loc -> label indexes (row labels, col labels)
#     iloc -> default index
#
#
#     at -> scaler value selection using label indexes
#     iat -> scaler value selection using default indexes
#
#     at and iat are way faster compare to loc, iloc

# %%
df
# Out:
#      name  maths  chemistry  physics
# 1001    A     50         60       80
# 1010    B     56         45       87
# 1007    C     56         45       87
# 1313    D     58         79       34
# 1111    E     34         76       87

# %%
df.loc[1313, "name"]
# Out:
# 'D'

# %%
df.loc[[1001, 1007, 1111],]
# Out:
#      name  maths  chemistry  physics
# 1001    A     50         60       80
# 1007    C     56         45       87
# 1111    E     34         76       87

# %%
df.loc[[1001, 1007, 1111], ['name', 'maths']]
# Out:
#      name  maths
# 1001    A     50
# 1007    C     56
# 1111    E     34

# %%
df.loc[1001:1313, ::2]
# Out:
#      name  chemistry
# 1001    A         60
# 1010    B         45
# 1007    C         45
# 1313    D         79

# %%
df
# Out:
#      name  maths  chemistry  physics
# 1001    A     50         60       80
# 1010    B     56         45       87
# 1007    C     56         45       87
# 1313    D     58         79       34
# 1111    E     34         76       87

# %%
df.iloc[[0, 2, 3], [0, 3, 1]]
# Out:
#      name  physics  maths
# 1001    A       80     50
# 1007    C       87     56
# 1313    D       34     58

# %%
df.iloc[[0, 2, 4]]
# Out:
#      name  maths  chemistry  physics
# 1001    A     50         60       80
# 1007    C     56         45       87
# 1111    E     34         76       87

# %%
df.loc[df['maths'] <= 50, 'maths'] += 10

# %%
df
# Out:
#      name  maths  chemistry  physics
# 1001    A     60         60       80
# 1010    B     56         45       87
# 1007    C     56         45       87
# 1313    D     58         79       34
# 1111    E     44         76       87

# %%
df.loc[ (df['maths']<=50)|(df['physics']>=87), ] # update
# Out:
#      name  maths  chemistry  physics
# 1010    B     56         45       87
# 1007    C     56         45       87
# 1111    E     44         76       87

# %%
df.query("maths <= 50 or physics>=87")# need to look specif data based on condition
# Out:
#      name  maths  chemistry  physics
# 1010    B     56         45       87
# 1007    C     56         45       87
# 1111    E     44         76       87

# %%
df[["name", "maths"]].plot(kind="bar", x="name", y="maths")
# Out:
# <AxesSubplot:xlabel='name'>

# %%
df
# Out:
#      name  maths  chemistry  physics
# 1001    A     60         60       80
# 1010    B     56         45       87
# 1007    C     56         45       87
# 1313    D     58         79       34
# 1111    E     44         76       87

# %%
df["% marks"] = (df['maths']+df['chemistry']+df['physics'])/3

# %%
df
# Out:
#      name  maths  chemistry  physics    % marks
# 1001    A     60         60       80  66.666667
# 1010    B     56         45       87  62.666667
# 1007    C     56         45       87  62.666667
# 1313    D     58         79       34  57.000000
# 1111    E     44         76       87  69.000000

# %%
df.assign(
    age = [13, 15, 16, 13, 15],
    gender = pd.Series(["M", "F", "F", "M", "F"], [1001, 1111, 1313, 1010, 1007])
) # we will get a new data frame
# Out:
#      name  maths  chemistry  physics    % marks  age gender
# 1001    A     60         60       80  66.666667   13      M
# 1010    B     56         45       87  62.666667   15      M
# 1007    C     56         45       87  62.666667   16      F
# 1313    D     58         79       34  57.000000   13      F
# 1111    E     44         76       87  69.000000   15      F

# %% [markdown]
#     GroupBy
#     Apply
#     ...

# %% [markdown]
# make 10 questions on each data set
#
#     select any 3 datasets of your interest (kaggle)

# %%
# %%writefile students.csv
# name,maths,chemistry,physics
# sachin,80,90,80
# rajat,100,60,80
# kushal,60,70,80
# yadavendra,67,67,87
# Out:
# Writing students.csv

# %%
df = pd.read_csv("students.csv")

# %%
df.index = [1010, 1312, 1012, 1111]

# %%
df
# Out:
#             name  maths  chemistry  physics
# 1010      sachin     80         90       80
# 1312       rajat    100         60       80
# 1012      kushal     60         70       80
# 1111  yadavendra     67         67       87

# %%
ix = df['maths'].argmax()

df.iloc[ix, [0, 1]]
# Out:
# name     rajat
# maths      100
# Name: 1312, dtype: object

# %% [markdown]
# Q1. Who is the tooper maths

# %%
# your code goes here

# %% [markdown]
# Q2. What is Average Result of Maths Subject

# %%
# your codes goes here

# %% [markdown]
# ##### Matplotlib
